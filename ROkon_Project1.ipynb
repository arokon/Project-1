# %%
import pandas as pd

# %%
dc_prop = pd.read_csv('datasets/DC_Properties.csv')

# %%
dc_prop.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
dc_prop.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
dc_prop.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
dc_prop.shape
# Out:
# (158957, 49)

# %%
dc_prop.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %% [markdown]
# List columns by the count of values (non NA)

# %%
dc_prop.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %% [markdown]
# Find average number of bathrooms

# %%
dc_prop['BATHRM'].mean()
# Out:
# 1.810678359556358

# %% [markdown]
# LIST and view Prices by counts of the value

# %%
dc_prop['PRICE'].value_counts()
# Out:
# 350000.0     595
# 250000.0     536
# 300000.0     523
# 450000.0     519
# 375000.0     488
# 325000.0     482
# 550000.0     459
# 275000.0     455
# 500000.0     426
# 320000.0     425
# 200000.0     422
# 425000.0     419
# 600000.0     403
# 315000.0     402
# 330000.0     396
# 650000.0     387
# 525000.0     387
# 285000.0     377
# 225000.0     376
# 265000.0     374
# 310000.0     371
# 475000.0     364
# 360000.0     364
# 260000.0     360
# 280000.0     352
# 385000.0     352
# 335000.0     352
# 220000.0     349
# 240000.0     348
# 230000.0     347
#             ...
# 168700.0       1
# 674755.0       1
# 5397500.0      1
# 168670.0       1
# 674670.0       1
# 468400.0       1
# 337325.0       1
# 1096000.0      1
# 337562.0       1
# 1350250.0      1
# 337575.0       1
# 117164.0       1
# 84461.0        1
# 468890.0       1
# 84450.0        1
# 84449.0        1
# 503850.0       1
# 337750.0       1
# 675490.0       1
# 114620.0       1
# 466250.0       1
# ...

# %% [markdown]
# List and view ZIPCODES's using dataframe with no missing values

# %%
df_no_missing['ZIPCODE']
# Out:
# 0         20009.0
# 1         20009.0
# 2         20009.0
# 3         20009.0
# 4         20009.0
# 5         20009.0
# 6         20009.0
# 7         20009.0
# 8         20009.0
# 9         20009.0
# 10        20009.0
# 11        20009.0
# 12        20009.0
# 13        20009.0
# 14        20009.0
# 15        20009.0
# 16        20009.0
# 17        20009.0
# 18        20009.0
# 19        20009.0
# 20        20009.0
# 21        20009.0
# 22        20009.0
# 23        20009.0
# 24        20009.0
# 25        20009.0
# 26        20009.0
# 27        20009.0
# 28        20009.0
# 29        20009.0
#            ...
# 158927    20001.0
# 158928    20001.0
# 158929    20001.0
# 158930    20001.0
# 158931    20001.0
# 158932    20001.0
# 158933    20001.0
# 158934    20001.0
# 158935    20001.0
# 158936    20001.0
# 158937    20001.0
# 158938    20001.0
# 158939    20001.0
# 158940    20001.0
# 158941    20001.0
# 158942    20001.0
# 158943    20001.0
# 158944    20001.0
# 158945    20001.0
# ...

# %%
df_no_missing = dc_prop.fillna(0)

# %%
df_no_missing['PRICE'].max()
# Out:
# 137427545.0

# %%
df_no_missing['PRICE'].min()
# Out:
# 0.0

# %% [markdown]
# Group ZipCode by Price to determine the zipcode with highest average property prices

# %%
df_no_missing['ZIPCODE'].groupby(df_no_missing['PRICE']).mean()
# Out:
# PRICE
# 0.0            20012.997382
# 1.0            20013.400000
# 10.0           20009.500000
# 250.0          20008.285714
# 500.0          20001.000000
# 936.0          20001.000000
# 1000.0         20016.000000
# 1377.0         20009.000000
# 2000.0         20014.500000
# 3000.0         20015.000000
# 3270.0         20036.000000
# 3523.0         20032.000000
# 3997.0         20019.000000
# 4101.0         20032.000000
# 4156.0         20012.000000
# 4500.0         20009.000000
# 4850.0         20020.000000
# 5000.0         20006.250000
# 5115.0         20019.000000
# 5185.0         20019.000000
# 5247.0         20010.000000
# 5400.0         20010.000000
# 5453.0         20020.000000
# 5522.0         20019.000000
# 5643.0         20001.000000
# 5964.0         20002.000000
# 6000.0         20005.500000
# 6826.0         20020.000000
# 6950.0         20005.000000
# 7000.0         20020.000000
#                    ...
# 7950000.0      20008.000000
# 8000000.0      20007.000000
# ...
