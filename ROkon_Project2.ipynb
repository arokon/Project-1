# %%
import pandas as pd
import numpy as np

location = "nyc-rolling-sales.csv"
df = pd.read_csv(location)
df.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %%
df[df['SALE PRICE'] != np.nan]
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 1               5        1  ALPHABET CITY
# 2               6        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# 5               9        1  ALPHABET CITY
# 6              10        1  ALPHABET CITY
# 7              11        1  ALPHABET CITY
# 8              12        1  ALPHABET CITY
# 9              13        1  ALPHABET CITY
# 10             14        1  ALPHABET CITY
# 11             15        1  ALPHABET CITY
# 12             16        1  ALPHABET CITY
# 13             17        1  ALPHABET CITY
# 14             18        1  ALPHABET CITY
# 15             19        1  ALPHABET CITY
# 16             20        1  ALPHABET CITY
# 17             21        1  ALPHABET CITY
# 18             22        1  ALPHABET CITY
# 19             23        1  ALPHABET CITY
# 20             24        1  ALPHABET CITY
# ...

# %%
origNum = df.shape
origNum
# Out:
# (84548, 22)

# %%
df['SALE PRICE'] = pd.to_numeric(df['SALE PRICE'],errors='coerce')

# %%
df['SALE PRICE']
# Out:
# 0         6625000.0
# 1               NaN
# 2               NaN
# 3         3936272.0
# 4         8000000.0
# 5               NaN
# 6         3192840.0
# 7               NaN
# 8               NaN
# 9        16232000.0
# 10              NaN
# 11       10350000.0
# 12              1.0
# 13         499000.0
# 14             10.0
# 15         529500.0
# 16         423000.0
# 17         501000.0
# 18         450000.0
# 19         510000.0
# 20              NaN
# 21         350000.0
# 22       11900000.0
# 23       11900000.0
# 24         350000.0
# 25         404000.0
# 26         535000.0
# 27        1400000.0
# 28         866000.0
# 29         355000.0
#             ...
# 84518      875000.0
# 84519      875000.0
# 84520      840000.0
# 84521      772500.0
# 84522      740000.0
# 84523           NaN
# 84524           NaN
# 84525           NaN
# 84526      590000.0
# 84527      580000.0
# 84528      550000.0
# 84529      545000.0
# 84530      800000.0
# 84531      642500.0
# ...

# %%
hasSale_df = df.dropna(axis = 0, how='any')

# %%
hasSale_df.shape
hasSale_df
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# 6              10        1  ALPHABET CITY
# 9              13        1  ALPHABET CITY
# 11             15        1  ALPHABET CITY
# 12             16        1  ALPHABET CITY
# 13             17        1  ALPHABET CITY
# 14             18        1  ALPHABET CITY
# 15             19        1  ALPHABET CITY
# 16             20        1  ALPHABET CITY
# 17             21        1  ALPHABET CITY
# 18             22        1  ALPHABET CITY
# 19             23        1  ALPHABET CITY
# 21             25        1  ALPHABET CITY
# 22             26        1  ALPHABET CITY
# 23             27        1  ALPHABET CITY
# 24             28        1  ALPHABET CITY
# 25             29        1  ALPHABET CITY
# 26             30        1  ALPHABET CITY
# 27             31        1  ALPHABET CITY
# ...

# %%
noDupes_df = hasSale_df.drop_duplicates()
noDupes_df.shape
# Out:
# (69987, 22)

# %%
noDupes_df['GROSS SQUARE FEET'] = pd.to_numeric(noDupes_df['GROSS SQUARE FEET'],errors='coerce')

# %%
import seaborn as sns
correlation_df = noDupes_df.filter(['SALE PRICE', 'GROSS SQUARE FEET', 'BOROUGH', 'RESIDENTIAL UNITS','TOTAL UNITS'], axis = 1)
sns.heatmap(correlation_df.corr(), vmin = -1, annot = True)
#correlation_df['GROSS SQUARE FEET'].dtypes

# %%
noDupes_df.columns
# Out:
# Index(['Unnamed: 0', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
correlation_df = noDupes_df.filter(['SALE PRICE', 'BOROUGH'], axis = 1)
sns.boxplot(x = 'BOROUGH',y = 'SALE PRICE', data = correlation_df)

# %%
correlation_df = noDupes_df.filter(['SALE PRICE', 'TOTAL UNITS'], axis = 1)
sns.lmplot(x = 'TOTAL UNITS',y = 'SALE PRICE', data = correlation_df)

# %%
sns.distplot(noDupes_df['SALE PRICE'])

# %%
sns.lmplot(x = 'YEAR BUILT', y ='SALE PRICE',data = noDupes_df)

# %%
noDupes_df.columns
# Out:
# Index(['Unnamed: 0', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')
